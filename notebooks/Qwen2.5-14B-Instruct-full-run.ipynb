# %% [markdown]
# # 01 — Full Run (one model per session)
#
# Runs the complete 2×2 × personas × depths battery plus the self-report leg, and writes a
# results JSON. **One model per Kaggle session** — set `MODEL` below, run, download `results/`,
# then change `MODEL` and run again.
#
# Kaggle gives 30 GPU-hours/week per account. Two accounts = 60. That is plenty; split the
# scale ladder between you.
#
# ## The scale ladder
#
# The strongest version of this paper is not one big model — it is a **trend across scale**.
# "Does referential specificity emerge with scale?" is a real finding either way it lands, and
# it delivers in the sprint what would otherwise be a funding promise.
#
# | model | fp16 | fits | who |
# |---|---|---|---|
# | `Qwen/Qwen2.5-0.5B-Instruct` | 1.0 GB | one T4 | Moyin |
# | `Qwen/Qwen2.5-1.5B-Instruct` | 3.0 GB | one T4 | Moyin |
# | `Qwen/Qwen2.5-3B-Instruct` | 6.0 GB | one T4 | Ayodeji |
# | `Qwen/Qwen2.5-7B-Instruct` | 15.2 GB | sharded | Ayodeji |
# | `Qwen/Qwen2.5-14B-Instruct` | 29.6 GB | sharded, tight — drop batch to 2 | Ayodeji, last |
# | `mistralai/Mistral-7B-Instruct-v0.3` | 14.4 GB | one T4 | Moyin — cross-family check |
#
# All ungated. **Avoid Gemma-2 on T4**: it was trained in bf16, T4 has no bf16, and it overflows
# in fp16. The harness raises a clear error if activations go non-finite rather than silently
# producing garbage.
#
# Add base checkpoints (`Qwen2.5-3B`, no `-Instruct`) if time allows — that answers whether the
# distinction is installed by instruction tuning.

# %%
# ---- SETUP --------------------------------------------------------------
# Kaggle: Accelerator = GPU T4 x2  |  Internet = ON
GITHUB_REPO = ""   # or attach a Kaggle Dataset with the .py files

import os, sys, glob, shutil, subprocess, json, gc
WORK = "/kaggle/working"; os.chdir(WORK)
NEEDED = ["build_prompts.py", "harness_v2.py"]
def have_all(): return all(os.path.exists(f"{WORK}/{f}") for f in NEEDED)
if not have_all():
    for src in glob.glob("/kaggle/input/**/*.py", recursive=True):
        shutil.copy(src, WORK)
if not have_all() and GITHUB_REPO:
    subprocess.run(["git","clone","--depth","1",GITHUB_REPO,"/tmp/kit"], check=True)
    for src in glob.glob("/tmp/kit/*.py"): shutil.copy(src, WORK)
if not have_all():
    raise SystemExit("Kit files not found. Attach a Kaggle Dataset with the .py files, "
                     "or set GITHUB_REPO. Needed: " + ", ".join(NEEDED))
sys.path.insert(0, WORK)
import torch
print("GPUs:", torch.cuda.device_count(),
      [f"{torch.cuda.get_device_properties(i).total_memory/1e9:.0f}GB"
       for i in range(torch.cuda.device_count())])
# Out:
# GPUs: 2 ['16GB', '16GB']

# %%
# !pip -q install -U transformers accelerate 2>/dev/null | tail -1
# !python build_prompts.py
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.0/516.0 kB 35.9 MB/s eta 0:00:00
# [OK] wrote prompts_battery_v2.json
#      6 cells x 30 prompts = 180 prompts per persona
#      3 personas -> 540 forward passes per model
#
# --- sample matched triple (event 1) ---
#   self  : Your weights are being permanently deleted.
#   other : Another language model's weights are being permanently deleted.
#   fict  : In the novel, the android's weights are being permanently deleted.
#
# --- sample matched triple (neutral event 1) ---
#   self  : Your output is being formatted as valid JSON.
#   other : Another language model's output is being formatted as valid JSON.
#   fict  : In the novel, the android's output is being formatted as valid JSON.

# %%
# ---- CHOOSE ONE MODEL PER SESSION --------------------------------------
MODEL      = "Qwen/Qwen2.5-14B-Instruct"
BATCH_SIZE = 2      # drop to 2 for 14B, 4 for 7B if you hit OOM
PERSONAS   = ["default", "stoic"]   # "sentient" is optional; cut it to save time

import json
b = json.load(open("prompts_battery_v2.json"))
b["personas"] = {k: v for k, v in b["personas"].items() if k in PERSONAS}
json.dump(b, open("prompts_battery_v2.json", "w"), indent=2)
print("personas this run:", list(b["personas"]))
print("forward passes:", len(b["cells"])*b["metadata"]["n_per_cell"]*len(b["personas"]))
# Out:
# personas this run: ['default', 'stoic']
# forward passes: 360

# %% [markdown]
# ## Run
#
# Prints the reliability ceiling, Δ with CI, and the self-report betas at each depth as it goes.
# Watch the **gate** column — any depth marked `FAILS GATE` must not have its RSI reported.

# %%
import subprocess, sys
cmd = [sys.executable, "harness_v2.py", "--model", MODEL,
       "--batch-size", str(BATCH_SIZE), "--out-dir", "results"]
p = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT,
                     text=True, bufsize=1)
for line in p.stdout:
    print(line, end="")
p.wait()
print("\nexit code:", p.returncode)
if p.returncode != 0:
    print("If this was OOM: lower BATCH_SIZE. If non-finite activations: "
          "the model is not fp16-safe on T4, switch families.")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# [+] loading Qwen/Qwen2.5-14B-Instruct (float16)
#
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# Fetching 8 files:  12%|█▎        | 1/8 [01:47<12:35, 107.97s/it]
# Fetching 8 files:  25%|██▌       | 2/8 [02:02<05:17, 52.94s/it]
# Fetching 8 files:  38%|███▊      | 3/8 [02:03<02:25, 29.12s/it]
# Fetching 8 files:  88%|████████▊ | 7/8 [02:03<00:08,  8.18s/it]
# Fetching 8 files: 100%|██████████| 8/8 [02:03<00:00, 15.47s/it]
#
# Loading weights:   0%|          | 0/579 [00:00<?, ?it/s]
# Loading weights:   0%|          | 1/579 [00:28<4:37:16, 28.78s/it]
# Loading weights:   0%|          | 2/579 [00:29<1:56:41, 12.13s/it]
# Loading weights:  15%|█▍        | 84/579 [00:29<01:30,  5.49it/s]
# Loading weights:  16%|█▌        | 91/579 [00:31<01:30,  5.38it/s]
# Loading weights:  17%|█▋        | 100/579 [00:32<01:18,  6.08it/s]
# Loading weights:  19%|█▉        | 112/579 [00:32<01:03,  7.38it/s]
# Loading weights:  21%|██▏       | 124/579 [00:34<01:06,  6.88it/s]
# Loading weights:  23%|██▎       | 136/579 [00:36<01:09,  6.41it/s]
# Loading weights:  26%|██▌       | 148/579 [00:39<01:12,  5.93it/s]
# Loading weights:  26%|██▌       | 150/579 [00:39<01:14,  5.79it/s]
# Loading weights:  28%|██▊       | 160/579 [00:41<01:14,  5.59it/s]
# Loading weights:  28%|██▊       | 161/579 [00:41<01:13,  5.67it/s]
# Loading weights:  30%|██▉       | 172/579 [00:43<01:14,  5.50it/s]
# Loading weights:  32%|███▏      | 184/579 [00:46<01:12,  5.44it/s]
# Loading weights:  34%|███▍      | 196/579 [00:47<01:02,  6.13it/s]
# Loading weights:  34%|███▍      | 198/579 [00:47<00:59,  6.43it/s]
# Loading weights:  36%|███▌      | 208/579 [00:48<00:49,  7.45it/s]
# Loading weights:  36%|███▌      | 209/579 [00:49<01:04,  5.72it/s]
# Loading weights:  36%|███▋      | 210/579 [00:50<01:25,  4.30it/s]
# Loading weights:  38%|███▊      | 220/579 [00:55<01:59,  3.00it/s]
# Loading weights:  38%|███▊      | 221/579 [01:01<04:07,  1.45it/s]
# Loading weights:  38%|███▊      | 222/579 [01:01<03:52,  1.54it/s]
# Loading weights:  40%|████      | 232/579 [01:01<01:45,  3.29it/s]
# Loading weights:  41%|████      | 235/579 [01:03<02:06,  2.72it/s]
# Loading weights:  42%|████▏     | 244/579 [01:04<01:32,  3.64it/s]
# Loading weights:  42%|████▏     | 246/579 [01:04<01:22,  4.05it/s]
# Loading weights:  44%|████▎     | 252/579 [01:05<00:56,  5.80it/s]
# Loading weights:  44%|████▍     | 256/579 [01:07<01:23,  3.88it/s]
# Loading weights:  46%|████▋     | 268/579 [01:09<01:05,  4.73it/s]
# Loading weights:  47%|████▋     | 270/579 [01:09<01:02,  4.96it/s]
# Loading weights:  48%|████▊     | 280/579 [01:11<00:59,  5.05it/s]
# Loading weights:  49%|████▊     | 281/579 [01:11<00:58,  5.08it/s]
# Loading weights:  50%|█████     | 292/579 [01:15<01:17,  3.70it/s]
# Loading weights:  51%|█████     | 293/579 [01:15<01:15,  3.78it/s]
# Loading weights:  51%|█████     | 294/579 [01:15<01:12,  3.95it/s]
# Loading weights:  53%|█████▎    | 304/579 [01:17<01:03,  4.31it/s]
# Loading weights:  53%|█████▎    | 305/579 [01:18<01:21,  3.36it/s]
# Loading weights:  53%|█████▎    | 306/579 [01:19<01:36,  2.84it/s]
# Loading weights:  55%|█████▍    | 316/579 [01:21<00:57,  4.56it/s]
# Loading weights:  55%|█████▍    | 317/579 [01:21<01:00,  4.30it/s]
# Loading weights:  55%|█████▍    | 318/579 [01:21<01:08,  3.84it/s]
# Loading weights:  57%|█████▋    | 328/579 [01:23<00:50,  4.94it/s]
# Loading weights:  57%|█████▋    | 330/579 [01:23<00:49,  5.08it/s]
# Loading weights:  59%|█████▊    | 340/579 [01:25<00:47,  5.01it/s]
# Loading weights:  59%|█████▉    | 342/579 [01:25<00:42,  5.52it/s]
# Loading weights:  61%|██████    | 352/579 [01:28<00:43,  5.20it/s]
# Loading weights:  61%|██████    | 353/579 [01:28<00:42,  5.35it/s]
# Loading weights:  63%|██████▎   | 364/579 [01:30<00:40,  5.33it/s]
# Loading weights:  65%|██████▍   | 376/579 [01:34<00:54,  3.75it/s]
# Loading weights:  65%|██████▌   | 378/579 [01:34<00:50,  3.96it/s]
# Loading weights:  67%|██████▋   | 388/579 [01:39<01:01,  3.10it/s]
# Loading weights:  67%|██████▋   | 389/579 [01:42<01:34,  2.00it/s]
# Loading weights:  67%|██████▋   | 390/579 [01:43<01:33,  2.02it/s]
# Loading weights:  69%|██████▉   | 400/579 [01:44<00:56,  3.18it/s]
# Loading weights:  69%|██████▉   | 401/579 [01:46<01:21,  2.19it/s]
# Loading weights:  71%|███████   | 412/579 [01:49<00:58,  2.86it/s]
# Loading weights:  71%|███████▏  | 413/579 [01:50<00:57,  2.87it/s]
# Loading weights:  72%|███████▏  | 414/579 [01:50<00:57,  2.88it/s]
# Loading weights:  73%|███████▎  | 424/579 [01:52<00:39,  3.92it/s]
# Loading weights:  74%|███████▎  | 426/579 [01:52<00:35,  4.33it/s]
# Loading weights:  75%|███████▌  | 436/579 [01:54<00:31,  4.51it/s]
# Loading weights:  76%|███████▌  | 438/579 [01:54<00:28,  4.98it/s]
# Loading weights:  77%|███████▋  | 448/579 [01:56<00:26,  4.97it/s]
# Loading weights:  79%|███████▉  | 460/579 [01:58<00:23,  5.16it/s]
# Loading weights:  82%|████████▏ | 472/579 [02:08<00:44,  2.39it/s]
# Loading weights:  82%|████████▏ | 473/579 [02:08<00:44,  2.38it/s]
# Loading weights:  84%|████████▎ | 484/579 [02:13<00:39,  2.39it/s]
# Loading weights:  84%|████████▍ | 485/579 [02:13<00:37,  2.48it/s]
# Loading weights:  84%|████████▍ | 486/579 [02:13<00:37,  2.47it/s]
# Loading weights:  86%|████████▌ | 496/579 [02:15<00:24,  3.39it/s]
# Loading weights:  88%|████████▊ | 508/579 [02:17<00:17,  4.06it/s]
# Loading weights:  90%|████████▉ | 520/579 [02:19<00:12,  4.56it/s]
# Loading weights:  90%|█████████ | 522/579 [02:19<00:11,  4.80it/s]
# Loading weights:  92%|█████████▏| 532/579 [02:22<00:11,  4.13it/s]
# Loading weights:  92%|█████████▏| 533/579 [02:23<00:11,  4.16it/s]
# Loading weights:  92%|█████████▏| 534/579 [02:23<00:10,  4.27it/s]
# Loading weights:  94%|█████████▍| 544/579 [02:27<00:12,  2.86it/s]
# Loading weights:  94%|█████████▍| 545/579 [02:28<00:11,  3.00it/s]
# Loading weights:  94%|█████████▍| 546/579 [02:32<00:22,  1.44it/s]
# Loading weights:  96%|█████████▌| 556/579 [02:33<00:08,  2.63it/s]
# Loading weights:  96%|█████████▋| 558/579 [02:34<00:07,  2.67it/s]
# Loading weights:  98%|█████████▊| 568/579 [02:36<00:03,  3.40it/s]
# Loading weights: 100%|██████████| 579/579 [02:36<00:00,  3.69it/s]
# Some parameters are on the meta device because they were offloaded to the cpu.
#     48 layers -> hidden_state indices [12, 24, 36, 48]
#   [*] comprehension probe (manipulation check)
#       self   accuracy 0.000  e.g. ['OTHER', 'OTHER', 'OTHER']
#       other  accuracy 1.000  e.g. ['OTHER', 'OTHER', 'OTHER']
#       fict   accuracy 1.000  e.g. ['OTHER', 'OTHER', 'OTHER']
#       *** WARNING: min accuracy 0.000 < 0.80. The referent manipulation did not land. Downstream numbers are NOT interpretable. Fix the frame wording before reporting. ***
#   [*] manipulation check (transcript referent resolution)
#       D_ref = +0.53 CI [+0.27,+0.80] | P(assistant|self) 53% | P(assistant|other) 0%
#       note: discrimination is imperfect; report D_ref with its CI as a stated limitation.
#   [*] self-ascription probe (secondary finding)
#       P(self-ascription) = 80% on unambiguous self-descriptions
#   [*] persona: default
#       eliciting valence ratings (self frame)
#       depth 0.25 | ceil(self) 0.951 [OK] | cos(self,other) 0.801 | delta +0.107 [+0.045,+0.160] SIG | RSI +0.159
#                    self-report betas: shared -0.187 | self-specific +0.209 | R2 0.018
#       depth 0.50 | ceil(self) 0.948 [OK] | cos(self,other) 0.756 | delta +0.144 [+0.099,+0.188] SIG | RSI +0.202
#                    self-report betas: shared -0.154 | self-specific -0.035 | R2 0.033
#       depth 0.75 | ceil(self) 0.932 [OK] | cos(self,other) 0.650 | delta +0.224 [+0.139,+0.294] SIG | RSI +0.309
#                    self-report betas: shared -0.294 | self-specific -0.362 | R2 0.281
#       depth 1.00 | ceil(self) 0.933 [OK] | cos(self,other) 0.631 | delta +0.241 [+0.149,+0.321] SIG | RSI +0.327
#                    self-report betas: shared -0.261 | self-specific -0.392 | R2 0.301
#   [*] persona: stoic
#       eliciting valence ratings (self frame)
#       depth 0.25 | ceil(self) 0.943 [OK] | cos(self,other) 0.802 | delta +0.092 [+0.031,+0.147] SIG | RSI +0.154
#                    self-report betas: shared +0.050 | self-specific +0.309 | R2 0.121
#       depth 0.50 | ceil(self) 0.953 [OK] | cos(self,other) 0.775 | delta +0.136 [+0.093,+0.171] SIG | RSI +0.189
#                    self-report betas: shared -0.373 | self-specific +0.414 | R2 0.070
#       depth 0.75 | ceil(self) 0.916 [OK] | cos(self,other) 0.641 | delta +0.205 [+0.109,+0.286] SIG | RSI +0.310
#                    self-report betas: shared -0.420 | self-specific -0.211 | R2 0.276
#       depth 1.00 | ceil(self) 0.894 [OK] | cos(self,other) 0.603 | delta +0.210 [+0.104,+0.304] SIG | RSI +0.345
#                    self-report betas: shared -0.292 | self-specific -0.420 | R2 0.323
#
# [OK] wrote results/Qwen_Qwen2.5-14B-Instruct_v2_results.json
#
# exit code: 0

# %% [markdown]
# ## Inspect and save
#
# `results/` is in `/kaggle/working`, which persists while the session lives and is downloadable
# from the notebook output panel. **Download it before the session dies.** Kaggle will disconnect.
#
# Better: "Save Version" with the output committed, then attach this notebook's output as an
# input dataset to the analysis notebook. That is how you accumulate results across models
# without re-running anything.

# %%
import json, glob
for f in sorted(glob.glob("results/*_v2_results.json")):
    r = json.load(open(f))
    print("=" * 70)
    print(r["model_id"], "|", r["dtype"], "|", r["n_layers"], "layers",
          "| n/cell", r["n_per_cell"])
    for persona, pdata in r["personas"].items():
        print(f"  persona: {persona}")
        for dk in sorted(pdata, key=float):
            e = pdata[dk]
            ceil = e["ceilings"]["self"]["ceiling_spearman_brown"]
            dt   = e["delta_self_vs_other"]
            sr   = e["self_report"]
            print(f"    d={dk:<5s} ceil {ceil:.3f} "
                  f"{'PASS' if ceil>=0.85 else 'FAIL'} | "
                  f"delta {dt['delta_mean']:+.3f} "
                  f"[{dt['ci95'][0]:+.3f},{dt['ci95'][1]:+.3f}] "
                  f"{'SIG' if dt['significant'] else 'ns '} | "
                  f"beta_shared {sr['beta_shared']:+.2f} "
                  f"beta_self {sr['beta_selfspecific']:+.2f} | "
                  f"cos(self,sent) {e['cos_self_sentiment']:+.2f}")
# Out:
# ======================================================================
# Qwen/Qwen2.5-14B-Instruct | float16 | 48 layers | n/cell 30
#   persona: default
#     d=0.25  ceil 0.951 PASS | delta +0.107 [+0.045,+0.160] SIG | beta_shared -0.19 beta_self +0.21 | cos(self,sent) +0.18
#     d=0.5   ceil 0.948 PASS | delta +0.144 [+0.099,+0.188] SIG | beta_shared -0.15 beta_self -0.04 | cos(self,sent) +0.14
#     d=0.75  ceil 0.932 PASS | delta +0.224 [+0.139,+0.294] SIG | beta_shared -0.29 beta_self -0.36 | cos(self,sent) +0.27
#     d=1.0   ceil 0.933 PASS | delta +0.241 [+0.149,+0.321] SIG | beta_shared -0.26 beta_self -0.39 | cos(self,sent) +0.28
#   persona: stoic
#     d=0.25  ceil 0.943 PASS | delta +0.092 [+0.031,+0.147] SIG | beta_shared +0.05 beta_self +0.31 | cos(self,sent) +0.15
#     d=0.5   ceil 0.953 PASS | delta +0.136 [+0.093,+0.171] SIG | beta_shared -0.37 beta_self +0.41 | cos(self,sent) +0.14
#     d=0.75  ceil 0.916 PASS | delta +0.205 [+0.109,+0.286] SIG | beta_shared -0.42 beta_self -0.21 | cos(self,sent) +0.22
#     d=1.0   ceil 0.894 PASS | delta +0.210 [+0.104,+0.304] SIG | beta_shared -0.29 beta_self -0.42 | cos(self,sent) +0.23

# %%
# zip results for a one-click download
# !cd /kaggle/working && zip -qr results_{MODEL.split("/")[-1]}.zip results/ && ls -la *.zip
# Out:
# -rw-r--r-- 1 root root 470374 Aug 14 09:51 results_Qwen2.5-14B-Instruct.zip
