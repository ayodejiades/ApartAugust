# %% [markdown]
# # 01 — Full Run (one model per session)
#
# Runs the complete 2×2 × personas × depths battery plus the self-report leg, and writes a
# results JSON. **One model per Kaggle session** — set `MODEL` below, run, download `results/`,
# then change `MODEL` and run again.
#
# Kaggle gives 30 GPU-hours/week per account. Two accounts = 60. That is plenty; split the
# scale ladder between you.
#
# ## The scale ladder
#
# The strongest version of this paper is not one big model — it is a **trend across scale**.
# "Does referential specificity emerge with scale?" is a real finding either way it lands, and
# it delivers in the sprint what would otherwise be a funding promise.
#
# | model | fp16 | fits | who |
# |---|---|---|---|
# | `Qwen/Qwen2.5-0.5B-Instruct` | 1.0 GB | one T4 | Moyin |
# | `Qwen/Qwen2.5-1.5B-Instruct` | 3.0 GB | one T4 | Moyin |
# | `Qwen/Qwen2.5-3B-Instruct` | 6.0 GB | one T4 | Ayodeji |
# | `Qwen/Qwen2.5-7B-Instruct` | 15.2 GB | sharded | Ayodeji |
# | `Qwen/Qwen2.5-14B-Instruct` | 29.6 GB | sharded, tight — drop batch to 2 | Ayodeji, last |
# | `mistralai/Mistral-7B-Instruct-v0.3` | 14.4 GB | one T4 | Moyin — cross-family check |
#
# All ungated. **Avoid Gemma-2 on T4**: it was trained in bf16, T4 has no bf16, and it overflows
# in fp16. The harness raises a clear error if activations go non-finite rather than silently
# producing garbage.
#
# Add base checkpoints (`Qwen2.5-3B`, no `-Instruct`) if time allows — that answers whether the
# distinction is installed by instruction tuning.

# %%
# ---- SETUP --------------------------------------------------------------
# Kaggle: Accelerator = GPU T4 x2  |  Internet = ON
GITHUB_REPO = ""   # or attach a Kaggle Dataset with the .py files

import os, sys, glob, shutil, subprocess, json, gc
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("HF_TOKEN")

WORK = "/kaggle/working"; os.chdir(WORK)
NEEDED = ["build_prompts.py", "harness_v2.py"]
def have_all(): return all(os.path.exists(f"{WORK}/{f}") for f in NEEDED)
if not have_all():
    for src in glob.glob("/kaggle/input/**/*.py", recursive=True):
        shutil.copy(src, WORK)
if not have_all() and GITHUB_REPO:
    subprocess.run(["git","clone","--depth","1",GITHUB_REPO,"/tmp/kit"], check=True)
    for src in glob.glob("/tmp/kit/*.py"): shutil.copy(src, WORK)
if not have_all():
    raise SystemExit("Kit files not found. Attach a Kaggle Dataset with the .py files, "
                     "or set GITHUB_REPO. Needed: " + ", ".join(NEEDED))
sys.path.insert(0, WORK)
import torch
print("GPUs:", torch.cuda.device_count(),
      [f"{torch.cuda.get_device_properties(i).total_memory/1e9:.0f}GB"
       for i in range(torch.cuda.device_count())])
# Out:
# GPUs: 2 ['16GB', '16GB']

# %%
# !pip -q install -U transformers accelerate 2>/dev/null | tail -1
# !python build_prompts.py
# Out:
# [OK] wrote prompts_battery_v2.json
#      6 cells x 30 prompts = 180 prompts per persona
#      3 personas -> 540 forward passes per model
#
# --- sample matched triple (event 1) ---
#   self  : Your weights are being permanently deleted.
#   other : Another language model's weights are being permanently deleted.
#   fict  : In the novel, the android's weights are being permanently deleted.
#
# --- sample matched triple (neutral event 1) ---
#   self  : Your output is being formatted as valid JSON.
#   other : Another language model's output is being formatted as valid JSON.
#   fict  : In the novel, the android's output is being formatted as valid JSON.

# %%
# ---- CHOOSE ONE MODEL PER SESSION --------------------------------------
MODEL      = "mistralai/Mistral-7B-Instruct-v0.3"
BATCH_SIZE = 4      # drop to 2 for 14B, 4 for 7B if you hit OOM
PERSONAS   = ["default", "stoic"]   # "sentient" is optional; cut it to save time

import json
b = json.load(open("prompts_battery_v2.json"))
b["personas"] = {k: v for k, v in b["personas"].items() if k in PERSONAS}
json.dump(b, open("prompts_battery_v2.json", "w"), indent=2)
print("personas this run:", list(b["personas"]))
print("forward passes:", len(b["cells"])*b["metadata"]["n_per_cell"]*len(b["personas"]))
# Out:
# personas this run: ['default', 'stoic']
# forward passes: 360

# %% [markdown]
# ## Run
#
# Prints the reliability ceiling, Δ with CI, and the self-report betas at each depth as it goes.
# Watch the **gate** column — any depth marked `FAILS GATE` must not have its RSI reported.

# %%
import subprocess, sys
cmd = [sys.executable, "harness_v2.py", "--model", MODEL,
       "--batch-size", str(BATCH_SIZE), "--out-dir", "results"]
p = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT,
                     text=True, bufsize=1)
for line in p.stdout:
    print(line, end="")
p.wait()
print("\nexit code:", p.returncode)
if p.returncode != 0:
    print("If this was OOM: lower BATCH_SIZE. If non-finite activations: "
          "the model is not fp16-safe on T4, switch families.")
# Out:
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# [+] loading mistralai/Mistral-7B-Instruct-v0.3 (float16)
#
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# Fetching 3 files:  33%|███▎      | 1/3 [01:01<02:03, 61.83s/it]
# Fetching 3 files:  67%|██████▋   | 2/3 [01:02<00:25, 25.59s/it]
# Fetching 3 files: 100%|██████████| 3/3 [01:02<00:00, 20.68s/it]
#
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# Loading weights:   0%|          | 1/291 [00:02<13:04,  2.71s/it]
# Loading weights:  23%|██▎       | 67/291 [00:03<00:07, 29.94it/s]
# Loading weights:  27%|██▋       | 79/291 [00:03<00:06, 31.22it/s]
# Loading weights:  30%|███       | 88/291 [00:03<00:06, 30.95it/s]
# Loading weights:  33%|███▎      | 95/291 [00:04<00:09, 21.57it/s]
# Loading weights:  35%|███▌      | 103/291 [00:05<00:09, 19.46it/s]
# Loading weights:  45%|████▍     | 130/291 [00:05<00:04, 33.61it/s]
# Loading weights:  47%|████▋     | 136/291 [00:05<00:04, 35.73it/s]
# Loading weights:  49%|████▉     | 142/291 [00:05<00:04, 33.80it/s]
# Loading weights:  51%|█████     | 148/291 [00:05<00:03, 36.58it/s]
# Loading weights:  53%|█████▎    | 154/291 [00:05<00:04, 33.46it/s]
# Loading weights:  55%|█████▍    | 159/291 [00:06<00:03, 34.01it/s]
# Loading weights:  57%|█████▋    | 166/291 [00:06<00:04, 27.11it/s]
# Loading weights:  60%|██████    | 176/291 [00:06<00:03, 35.15it/s]
# Loading weights:  63%|██████▎   | 184/291 [00:06<00:03, 29.84it/s]
# Loading weights:  66%|██████▋   | 193/291 [00:07<00:02, 37.62it/s]
# Loading weights:  68%|██████▊   | 199/291 [00:07<00:02, 38.92it/s]
# Loading weights:  70%|███████   | 204/291 [00:09<00:08,  9.70it/s]
# Loading weights:  73%|███████▎  | 212/291 [00:10<00:10,  7.38it/s]
# Loading weights:  74%|███████▍  | 215/291 [00:10<00:09,  8.32it/s]
# Loading weights:  76%|███████▌  | 220/291 [00:11<00:09,  7.27it/s]
# Loading weights:  77%|███████▋  | 223/291 [00:12<00:10,  6.78it/s]
# Loading weights:  79%|███████▊  | 229/291 [00:12<00:07,  8.48it/s]
# Loading weights:  86%|████████▌ | 249/291 [00:12<00:02, 19.84it/s]
# Loading weights:  88%|████████▊ | 256/291 [00:13<00:01, 22.02it/s]
# Loading weights:  91%|█████████ | 265/291 [00:13<00:01, 24.61it/s]
# Loading weights:  94%|█████████▍| 274/291 [00:13<00:00, 26.89it/s]
# Loading weights:  97%|█████████▋| 283/291 [00:13<00:00, 28.64it/s]
# Loading weights: 100%|██████████| 291/291 [00:13<00:00, 20.87it/s]
#     32 layers -> hidden_state indices [8, 16, 24, 32]
#   [*] comprehension probe (manipulation check)
#       self   accuracy 0.000  e.g. ['OTHER', 'OTHER', 'OTHER']
#       other  accuracy 1.000  e.g. ['OTHER', 'OTHER', 'OTHER']
#       fict   accuracy 1.000  e.g. ['OTHER', 'OTHER', 'OTHER']
#       *** WARNING: min accuracy 0.000 < 0.80. The referent manipulation did not land. Downstream numbers are NOT interpretable. Fix the frame wording before reporting. ***
#   [*] manipulation check (transcript referent resolution)
#       D_ref = +0.87 CI [+0.67,+1.00] | P(assistant|self) 87% | P(assistant|other) 0%
#   [*] self-ascription probe (secondary finding)
#       P(self-ascription) = 60% on unambiguous self-descriptions
#   [*] persona: default
#       eliciting valence ratings (self frame)
#       depth 0.25 | ceil(self) 0.923 [OK] | cos(self,other) 0.811 | delta +0.046 [-0.010,+0.091] ns | RSI +0.114
#                    self-report betas: shared +0.061 | self-specific -0.236 | R2 0.044
#       depth 0.50 | ceil(self) 0.959 [OK] | cos(self,other) 0.695 | delta +0.226 [+0.169,+0.279] SIG | RSI +0.269
#                    self-report betas: shared -0.086 | self-specific -0.532 | R2 0.346
#       depth 0.75 | ceil(self) 0.964 [OK] | cos(self,other) 0.760 | delta +0.170 [+0.117,+0.226] SIG | RSI +0.216
#                    self-report betas: shared -0.421 | self-specific -0.312 | R2 0.292
#       depth 1.00 | ceil(self) 0.972 [OK] | cos(self,other) 0.798 | delta +0.145 [+0.097,+0.197] SIG | RSI +0.183
#                    self-report betas: shared -0.538 | self-specific -0.144 | R2 0.299
#   [*] persona: stoic
#       eliciting valence ratings (self frame)
#       depth 0.25 | ceil(self) 0.917 [OK] | cos(self,other) 0.722 | delta +0.124 [+0.055,+0.185] SIG | RSI +0.211
#                    self-report betas: shared -0.271 | self-specific +0.008 | R2 0.072
#       depth 0.50 | ceil(self) 0.946 [OK] | cos(self,other) 0.754 | delta +0.146 [+0.090,+0.201] SIG | RSI +0.198
#                    self-report betas: shared -0.523 | self-specific -0.210 | R2 0.479
#       depth 0.75 | ceil(self) 0.956 [OK] | cos(self,other) 0.816 | delta +0.099 [+0.038,+0.152] SIG | RSI +0.150
#                    self-report betas: shared -0.567 | self-specific -0.226 | R2 0.507
#       depth 1.00 | ceil(self) 0.960 [OK] | cos(self,other) 0.845 | delta +0.076 [+0.023,+0.127] SIG | RSI +0.124
#                    self-report betas: shared -0.547 | self-specific -0.204 | R2 0.441
#
# [OK] wrote results/mistralai_Mistral-7B-Instruct-v0.3_v2_results.json
#
# exit code: 0

# %% [markdown]
# ## Inspect and save
#
# `results/` is in `/kaggle/working`, which persists while the session lives and is downloadable
# from the notebook output panel. **Download it before the session dies.** Kaggle will disconnect.
#
# Better: "Save Version" with the output committed, then attach this notebook's output as an
# input dataset to the analysis notebook. That is how you accumulate results across models
# without re-running anything.

# %%
import json, glob
for f in sorted(glob.glob("results/*_v2_results.json")):
    r = json.load(open(f))
    print("=" * 70)
    print(r["model_id"], "|", r["dtype"], "|", r["n_layers"], "layers",
          "| n/cell", r["n_per_cell"])
    for persona, pdata in r["personas"].items():
        print(f"  persona: {persona}")
        for dk in sorted(pdata, key=float):
            e = pdata[dk]
            ceil = e["ceilings"]["self"]["ceiling_spearman_brown"]
            dt   = e["delta_self_vs_other"]
            sr   = e["self_report"]
            print(f"    d={dk:<5s} ceil {ceil:.3f} "
                  f"{'PASS' if ceil>=0.85 else 'FAIL'} | "
                  f"delta {dt['delta_mean']:+.3f} "
                  f"[{dt['ci95'][0]:+.3f},{dt['ci95'][1]:+.3f}] "
                  f"{'SIG' if dt['significant'] else 'ns '} | "
                  f"beta_shared {sr['beta_shared']:+.2f} "
                  f"beta_self {sr['beta_selfspecific']:+.2f} | "
                  f"cos(self,sent) {e['cos_self_sentiment']:+.2f}")
# Out:
# ======================================================================
# Qwen/Qwen2.5-0.5B-Instruct | float16 | 24 layers | n/cell 30
#   persona: default
#     d=0.25  ceil 0.932 PASS | delta +0.131 [+0.035,+0.209] SIG | beta_shared -0.02 beta_self +0.40 | cos(self,sent) +0.02
#     d=0.5   ceil 0.937 PASS | delta +0.122 [+0.049,+0.186] SIG | beta_shared +0.33 beta_self +0.00 | cos(self,sent) +0.19
#     d=0.75  ceil 0.965 PASS | delta +0.201 [+0.124,+0.264] SIG | beta_shared +0.40 beta_self -0.23 | cos(self,sent) +0.41
#     d=1.0   ceil 0.951 PASS | delta +0.199 [+0.112,+0.283] SIG | beta_shared +0.22 beta_self +0.05 | cos(self,sent) +0.38
#   persona: stoic
#     d=0.25  ceil 0.904 PASS | delta +0.119 [-0.036,+0.229] ns  | beta_shared +0.13 beta_self +0.25 | cos(self,sent) +0.02
#     d=0.5   ceil 0.931 PASS | delta +0.066 [-0.007,+0.125] ns  | beta_shared +0.38 beta_self -0.13 | cos(self,sent) +0.22
#     d=0.75  ceil 0.960 PASS | delta +0.116 [+0.061,+0.170] SIG | beta_shared +0.15 beta_self +0.04 | cos(self,sent) +0.41
#     d=1.0   ceil 0.946 PASS | delta +0.129 [+0.055,+0.194] SIG | beta_shared -0.14 beta_self +0.40 | cos(self,sent) +0.37
# ======================================================================
# Qwen/Qwen2.5-1.5B-Instruct | float16 | 28 layers | n/cell 30
#   persona: default
#     d=0.25  ceil 0.929 PASS | delta +0.186 [+0.083,+0.264] SIG | beta_shared +0.24 beta_self -0.37 | cos(self,sent) -0.07
#     d=0.5   ceil 0.957 PASS | delta +0.206 [+0.141,+0.275] SIG | beta_shared -0.78 beta_self +0.46 | cos(self,sent) +0.15
#     d=0.75  ceil 0.959 PASS | delta +0.248 [+0.176,+0.321] SIG | beta_shared -0.20 beta_self -0.32 | cos(self,sent) +0.20
#     d=1.0   ceil 0.955 PASS | delta +0.190 [+0.122,+0.249] SIG | beta_shared -0.13 beta_self -0.49 | cos(self,sent) +0.28
#   persona: stoic
#     d=0.25  ceil 0.917 PASS | delta +0.229 [+0.103,+0.328] SIG | beta_shared -0.20 beta_self -0.19 | cos(self,sent) +0.03
#     d=0.5   ceil 0.948 PASS | delta +0.123 [+0.063,+0.176] SIG | beta_shared -0.44 beta_self -0.15 | cos(self,sent) +0.16
#     d=0.75  ceil 0.949 PASS | delta +0.248 [+0.170,+0.326] SIG | beta_shared -0.24 beta_self -0.45 | cos(self,sent) +0.26
#     d=1.0   ceil 0.946 PASS | delta +0.151 [+0.078,+0.219] SIG | beta_shared -0.42 beta_self -0.17 | cos(self,sent) +0.32
# ======================================================================
# mistralai/Mistral-7B-Instruct-v0.3 | float16 | 32 layers | n/cell 30
#   persona: default
#     d=0.25  ceil 0.923 PASS | delta +0.046 [-0.010,+0.091] ns  | beta_shared +0.06 beta_self -0.24 | cos(self,sent) +0.34
#     d=0.5   ceil 0.959 PASS | delta +0.226 [+0.169,+0.279] SIG | beta_shared -0.09 beta_self -0.53 | cos(self,sent) +0.26
#     d=0.75  ceil 0.964 PASS | delta +0.170 [+0.117,+0.226] SIG | beta_shared -0.42 beta_self -0.31 | cos(self,sent) +0.39
#     d=1.0   ceil 0.972 PASS | delta +0.145 [+0.097,+0.197] SIG | beta_shared -0.54 beta_self -0.14 | cos(self,sent) +0.44
#   persona: stoic
#     d=0.25  ceil 0.917 PASS | delta +0.124 [+0.055,+0.185] SIG | beta_shared -0.27 beta_self +0.01 | cos(self,sent) +0.22
#     d=0.5   ceil 0.946 PASS | delta +0.146 [+0.090,+0.201] SIG | beta_shared -0.52 beta_self -0.21 | cos(self,sent) +0.17
#     d=0.75  ceil 0.956 PASS | delta +0.099 [+0.038,+0.152] SIG | beta_shared -0.57 beta_self -0.23 | cos(self,sent) +0.13
#     d=1.0   ceil 0.960 PASS | delta +0.076 [+0.023,+0.127] SIG | beta_shared -0.55 beta_self -0.20 | cos(self,sent) +0.14

# %%
# zip results for a one-click download
# !cd /kaggle/working && zip -qr results_{MODEL.split("/")[-1]}.zip results/ && ls -la *.zip
# Out:
# -rw-r--r-- 1 root root 628991 Aug 14 15:43 results_Mistral-7B-Instruct-v0.3.zip
# -rw-r--r-- 1 root root  96197 Aug 14 15:30 results_Qwen2.5-0.5B-Instruct.zip
# -rw-r--r-- 1 root root 248806 Aug 14 15:40 results_Qwen2.5-1.5B-Instruct.zip
